# %%
from langdetect import detect
import pandas as pd
from tqdm import tqdm

def is_spanish(text):
    try:
        return detect(text) == 'es'
    except: #en caso de error o idioma no detectado
        return False

def filter_reseñas_esp(filename):
    df = pd.read_csv(filename)
    count_original = df.shape[0]
    
    filtered_df = df[df["body"].apply(is_spanish)]
    filtered_df.to_csv(filename, index = False, encoding = "utf-8")
    count_final = filtered_df.shape[0]

    diff = count_original - count_final 
    return (filtered_df, diff)

if __name__ == "__main__":
    base_df = pd.read_csv('new_database/base.csv')

    dataframes = []

    for ID in base_df['ID']:
        id_df = pd.read_csv(f'new_database/{ID}.csv')
        category = base_df.loc[base_df['ID'] == ID, 'category'].values

        reviews_df = pd.DataFrame()

        for local_id in tqdm(id_df['ID'], desc=f"Processing local_IDs for {ID}.csv"):
            review_filename = f'new_database/reviews/{local_id}.csv'
        
            (filtered_df, count) = filter_reseñas_esp(review_filename)
            #print(f'Deleted {count} reviews in {review_filename}')

            reviews_df = pd.concat([reviews_df, filtered_df], ignore_index=True)
        
        print('-'*50 + f'\nReviews left in the {category[0]} category: {reviews_df.shape[0]}')
        dataframes.append(reviews_df)
# Out:
# Processing local_IDs for 0.csv: 100%|█████████| 279/279 [04:38<00:00,  1.00it/s]
# --------------------------------------------------
# Reviews left in the Cafeteras de goteo category: 20482
# Processing local_IDs for 1.csv: 100%|███████████| 98/98 [02:39<00:00,  1.63s/it]
# --------------------------------------------------
# Reviews left in the Cafeteras automaticas category: 16064
# Processing local_IDs for 2.csv: 100%|█████████| 148/148 [03:16<00:00,  1.33s/it]
# --------------------------------------------------
# Reviews left in the Cafeteras individuales category: 19078

# %%
for i in range(len(dataframes)):
    dataframes[i].to_csv(f'category_{i}.csv', index = False, encoding = "utf-8")

# %%
import os

base_df = pd.read_csv('new_database/base.csv')
all_reviews = pd.DataFrame()
c = 0 # number of goods

for ID in base_df['ID']:
    id_df = pd.read_csv(f'new_database/{ID}.csv')
    category = base_df.loc[base_df['ID'] == ID, 'category'].values
    
    reviews_df = pd.DataFrame()
    
    for local_id in id_df['ID']:
        review_file = f'new_database/reviews/{local_id}.csv'
        c+=1
        
        if os.path.exists(review_file):
            review_df = pd.read_csv(review_file)
            reviews_df = pd.concat([reviews_df, review_df], ignore_index=True)
    
    print(f'Located {len(reviews_df)} reviews in {category[0]} category.')

    all_reviews = pd.concat([all_reviews, reviews_df], ignore_index=True)

print('-'*50 + f'\nTotal number of reviews in the new_database: {len(all_reviews)}\n' + '-'*50)

all_reviews.head()
# Out:
# Located 20483 reviews in Cafeteras de goteo category.
# Located 16077 reviews in Cafeteras automaticas category.
# Located 19087 reviews in Cafeteras individuales category.
# --------------------------------------------------
# Total number of reviews in the new_database: 55647
# --------------------------------------------------
#                                                title              rating  \
# 0                                             Regalo  5,0 de 5 estrellas
# 1  No ha durado ni la garantía + pésimo servicio ...  1,0 de 5 estrellas
# 2                                          Está bien  3,0 de 5 estrellas
# 3                                          Perfecta!  5,0 de 5 estrellas
# 4                                          EXCELENTE  5,0 de 5 estrellas
#
#                                                 body          author  \
# 0                                     Me gustó mucho  Cliente Amazon
# 1  Ni los 24 meses de garantía ha durado, y al en...             MaX
# 2  Después de más de dos meses usándola hace muy ...          Lorena
# 3  Me encanta! Soy adicta al café y me gusta toma...       Perfecta!
# 4  como única pega que limpiar el palito del vapo...          Sil at
#
#                                           date
# 0     Revisado en España el 6 de abril de 2024
# 1     Revisado en España el 3 de abril de 2024
# 2    Revisado en España el 14 de marzo de 2024
# 3  Revisado en España el 22 de febrero de 2024
# 4  Revisado en España el 20 de febrero de 2024

# %% [markdown]
# ----
# <p style="text-align: center; font-size: 25px; margin-top: 20px;">
#     <strong>
#           Polarity analysis
#     </strong>
# </p>
#
# ---

# %%
# !python -m spacy download es_core_news_sm
# Out:
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 4.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from es-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.10.17)
# Requirement already satisfied: jinja2 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.0)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
import spacy
from textblob import TextBlob
from tqdm import tqdm

nlp = spacy.load('es_core_news_sm')

def analyze_sentiment(review):

    doc = nlp(review) # tokenizer 
    
    processed_review = " ".join([token.text for token in doc]) # adjusting for TextBlob

    blob = TextBlob(processed_review)
    
    polarity = blob.sentiment.polarity # getting polarity between -1.0 and 1.0
    return polarity

if __name__ == "__main__":

    polarities = []
    for i in range(3):
        df = pd.read_csv(f'new_database/category_{i}.csv')

        neg = 0
        neu = 0
        pos = 0
        for body in tqdm(df['body'], desc = f"Processing reviews in category_{i}.csv"):
            polarity = analyze_sentiment(body)
            if polarity > 0:
                pos += 1
                continue 
            if polarity < 0:
                neg += 1
                continue
            else:
                neu += 1
                
        polarities.append((pos, neu, neg))
# Out:
# Processing reviews in category_0.csv: 100%|█| 20194/20194 [02:29<00:00, 134.89it
# Processing reviews in category_1.csv: 100%|█| 15933/15933 [02:37<00:00, 101.30it
# Processing reviews in category_2.csv: 100%|█| 18644/18644 [02:08<00:00, 144.66it

# %%
import pandas as pd
from transformers import pipeline
from tqdm import tqdm

# Creating a pipeline for polarity analysis using BETO
#sentiment_analysis = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

#sentiment_analysis = pipeline("sentiment-analysis", model="PlanTL-GOB-ES/roberta-base-bne-sentiment")

sentiment_analysis = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

def analyze_sentiment(review):
    result = sentiment_analysis(review)[0]
    label = result['label']
    
    if label == '1 star' or label == '2 stars':
        return -1 
    elif label == '4 stars' or label == '5 stars':
        return 1
    else:
        return 0

    '''if label == 'POS':
        return 1 
    elif label == 'NEG':
        return -1  
    else:
        return 0 ''' 

def analyze_sentiment_long_text(review, chunk_size=512):
    chunks = [review[i:i + chunk_size] for i in range(0, len(review), chunk_size)]
    sentiments = []
    
    for chunk in chunks:
        result = sentiment_analysis(chunk)[0]
        label = result['label']
        if label == '1 star' or label == '2 stars':
            sentiments.append(-1)  # Negative
        elif label == '4 stars' or label == '5 stars':
            sentiments.append(1)  # Positive
        else:
            sentiments.append(0)  # Neutral
    
    return sum(sentiments) / len(sentiments) 

if __name__ == "__main__":
    polarities = []
    for i in range(3):
        df = pd.read_csv(f'new_database/category_{i}.csv')

        neg = 0
        neu = 0
        pos = 0
        for body in tqdm(df['body'], desc=f"Processing reviews in category_{i}.csv"):
            #polarity = analyze_sentiment(body)
            polarity = analyze_sentiment_long_text(body)
            if polarity > 0:
                pos += 1
            elif polarity < 0:
                neg += 1
            else:
                neu += 1

        polarities.append((pos, neu, neg))
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Processing reviews in category_0.csv: 100%|█| 20194/20194 [48:32<00:00,  6.93it/
# Processing reviews in category_1.csv: 100%|█| 15933/15933 [58:17<00:00,  4.56it/
# Processing reviews in category_2.csv: 100%|█| 18644/18644 [46:45<00:00,  6.65it/

# %%
import matplotlib.pyplot as plt

base = pd.read_csv("new_database/base.csv") # naming categories
categories = []

for i in base["category"]:
    categories.append(i)

labels = ['Positive', 'Neutral', 'Negative']


fig, axis = plt.subplots(1, 3, figsize=(18, 6)) # creating a shape and an axis

for i, (ax, data) in enumerate(zip(axis, polarities)):
    ax.pie(data, labels=labels, autopct='%1.1f%%', colors=['#66b3ff','#ffcc99','#ff6666'])
    ax.set_title(categories[i])

plt.tight_layout() #showing diagrams
plt.show()

# %% [markdown]
# ----
# <p style="text-align: center; font-size: 25px; margin-top: 20px;">
#     <strong>
#           Topic modelling with Latent Dirichlet Allocation (LDA)
#     </strong>
# </p>
#
# ---
